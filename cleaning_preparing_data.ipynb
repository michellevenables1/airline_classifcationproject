# %% [markdown]
# # Import CSV on Flight Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airline_delay_causes.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  year   month carrier            carrier_name airport  \
# 0           0  2003       6      AA  American Airlines Inc.     ABQ
# 1           1  2003       6      AA  American Airlines Inc.     ANC
# 2           2  2003       6      AA  American Airlines Inc.     ATL
# 3           3  2003       6      AA  American Airlines Inc.     AUS
# 4           4  2003       6      AA  American Airlines Inc.     BDL
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        307.0       56.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         90.0       27.0
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...        752.0      186.0
# 3       Austin, TX: Austin - Bergstrom International        842.0      174.0
# 4                Hartford, CT: Bradley International        383.0       55.0
#
#    carrier_ct  ...  late_aircraft_ct  arr_cancelled  arr_diverted   arr_delay  \
# ...

# %% [markdown]
# # Reset column names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', ' month', 'carrier', 'carrier_name', 'airport',
#        'airport_name', 'arr_flights', 'arr_del15', 'carrier_ct', ' weather_ct',
#        'nas_ct', 'security_ct', 'late_aircraft_ct', 'arr_cancelled',
#        'arr_diverted', ' arr_delay', ' carrier_delay', 'weather_delay',
#        'nas_delay', 'security_delay', 'late_aircraft_delay', 'Unnamed: 21'],
#       dtype='object')

# %%
df.columns = 'unnamed', 'year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name', 'total_arrival_flights', 'num_arr_delays', 'num_aircarrier_delay', 'num_weather_delay', 'num_nas_delay','num_security_delay', 'num_lateaircraft_delay', 'num_cancelled', 'num_diverted', 'tot_arr_delay_mins', 'carrier_delay_mins', 'weather_delay_mins', 'nas_delay_mins','security_delay_mins', 'lateaircraft_delay_mins', 'Unnamed'

# %%
df = df.drop(['Unnamed'], axis=1)
df = df.drop(['unnamed'], axis=1)

# %%
df.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2003      6      AA  American Airlines Inc.     ABQ
# 1  2003      6      AA  American Airlines Inc.     ANC
# 2  2003      6      AA  American Airlines Inc.     ATL
# 3  2003      6      AA  American Airlines Inc.     AUS
# 4  2003      6      AA  American Airlines Inc.     BDL
#
#                                         airport_name  total_arrival_flights  \
# 0  Albuquerque, NM: Albuquerque International Sun...                  307.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...                   90.0
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...                  752.0
# 3       Austin, TX: Austin - Bergstrom International                  842.0
# 4                Hartford, CT: Bradley International                  383.0
#
#    num_arr_delays  num_aircarrier_delay  num_weather_delay  ...  \
# 0            56.0                 14.68              10.79  ...
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'total_arrival_flights', 'num_arr_delays', 'num_aircarrier_delay',
#        'num_weather_delay', 'num_nas_delay', 'num_security_delay',
#        'num_lateaircraft_delay', 'num_cancelled', 'num_diverted',
#        'tot_arr_delay_mins', 'carrier_delay_mins', 'weather_delay_mins',
#        'nas_delay_mins', 'security_delay_mins', 'lateaircraft_delay_mins'],
#       dtype='object')

# %% [markdown]
# # Dealing with Null Values
#
# dropping rows with no number of flights and filling in num_arr_delays that are empty with 0

# %%
df.isna().sum()
# Out:
# year                         0
# month                        0
# carrier                      0
# carrier_name                 0
# airport                      0
# airport_name                 0
# total_arrival_flights      367
# num_arr_delays             423
# num_aircarrier_delay       367
# num_weather_delay          367
# num_nas_delay              367
# num_security_delay         367
# num_lateaircraft_delay     367
# num_cancelled              367
# num_diverted               367
# tot_arr_delay_mins         367
# carrier_delay_mins         367
# weather_delay_mins         367
# nas_delay_mins             367
# security_delay_mins        367
# lateaircraft_delay_mins    367
# dtype: int64

# %%
df = df[pd.notnull(df['total_arrival_flights'])]

# %%
df = df.fillna(0)

# %%
df.isna().sum()
# Out:
# year                       0
# month                      0
# carrier                    0
# carrier_name               0
# airport                    0
# airport_name               0
# total_arrival_flights      0
# num_arr_delays             0
# num_aircarrier_delay       0
# num_weather_delay          0
# num_nas_delay              0
# num_security_delay         0
# num_lateaircraft_delay     0
# num_cancelled              0
# num_diverted               0
# tot_arr_delay_mins         0
# carrier_delay_mins         0
# weather_delay_mins         0
# nas_delay_mins             0
# security_delay_mins        0
# lateaircraft_delay_mins    0
# dtype: int64

# %%
df.describe()
# Out:
#                 year          month  total_arrival_flights  num_arr_delays  \
# count  266378.000000  266378.000000          266378.000000   266378.000000
# mean     2010.865740       6.482348             398.836011       78.503626
# std         4.770152       3.420350            1058.662753      208.900404
# min      2003.000000       1.000000               1.000000        0.000000
# 25%      2007.000000       4.000000              62.000000       11.000000
# 50%      2010.000000       6.000000             128.000000       25.000000
# 75%      2015.000000       9.000000             287.000000       61.000000
# max      2019.000000      12.000000           21977.000000     6377.000000
#
#        num_aircarrier_delay  num_weather_delay  num_nas_delay  \
# count         266378.000000      266378.000000  266378.000000
# mean              21.993584           2.806395      26.339747
# std               48.028565          10.518730      90.737044
# ...

# %%
df.shape
# Out:
# (266378, 21)

# %%
df.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2003      6      AA  American Airlines Inc.     ABQ
# 1  2003      6      AA  American Airlines Inc.     ANC
# 2  2003      6      AA  American Airlines Inc.     ATL
# 3  2003      6      AA  American Airlines Inc.     AUS
# 4  2003      6      AA  American Airlines Inc.     BDL
#
#                                         airport_name  total_arrival_flights  \
# 0  Albuquerque, NM: Albuquerque International Sun...                  307.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...                   90.0
# 2  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...                  752.0
# 3       Austin, TX: Austin - Bergstrom International                  842.0
# 4                Hartford, CT: Bradley International                  383.0
#
#    num_arr_delays  num_aircarrier_delay  num_weather_delay  ...  \
# 0            56.0                 14.68              10.79  ...
# ...

# %% [markdown]
# # QUESTION:
# - Will my united flight be delayed?
# Target:
#        - United Airlines delayed
#        - United Airline not delayed
# - our DF needs to be united flights only from 2003 - 2019 (saved to csv)
#          - also have American, delta, southwest, jetblue data for more models!

# %%
df.tot_arr_delay_mins.median()
# Out:
# 1341.0

# %%
southwest_df = df[df['carrier']=='WN']

# %%
southwest_df.to_csv('wn_data.csv')

# %%
len(american_df)
# Out:
# 16438

# %%
len(united_df)
# Out:
# 16023

# %%
len(delta_df)
# Out:
# 23466

# %%
len(jetblue_df)
# Out:
# 9601

# %%
len(southwest_df)
# Out:
# 14389

# %%
ua_df = df[df['carrier']=='UA']

# %%
ua_ewr = ua_df[ua_df['airport']=='EWR']

# %%
ua_ewr = ua_ewr.drop(columns = ['carrier', 'carrier_name', 'airport', 'airport_name'])

# %%
ua_ewr.to_csv('united_ewr.csv')
